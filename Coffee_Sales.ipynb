# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Read data

# %%
data1 = pd.read_csv('index_1.csv')

# %%
data1
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3631  2025-03-23  2025-03-23 10:34:54.894      card  ANON-0000-0000-1158
# 3632  2025-03-23  2025-03-23 14:43:37.362      card  ANON-0000-0000-1315
# 3633  2025-03-23  2025-03-23 14:44:16.864      card  ANON-0000-0000-1315
# 3634  2025-03-23  2025-03-23 15:47:28.723      card  ANON-0000-0000-1316
# 3635  2025-03-23  2025-03-23 18:11:38.635      card  ANON-0000-0000-1275
#
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# 2     38.70  Hot Chocolate
# 3     28.90      Americano
# 4     38.70          Latte
# ...     ...            ...
# 3631  35.76     Cappuccino
# 3632  35.76          Cocoa
# 3633  35.76          Cocoa
# 3634  25.96      Americano
# 3635  35.76          Latte
#
# [3636 rows x 6 columns]

# %%
data2 = pd.read_csv('index_2.csv')

# %%
data2
# Out:
#            date             datetime cash_type  money  \
# 0    2025-02-08  2025-02-08 14:26:04      cash   15.0
# 1    2025-02-08  2025-02-08 14:28:26      cash   15.0
# 2    2025-02-08  2025-02-08 14:33:04      card   20.0
# 3    2025-02-08  2025-02-08 15:51:04      card   30.0
# 4    2025-02-08  2025-02-08 16:35:01      cash   27.0
# ..          ...                  ...       ...    ...
# 257  2025-03-23  2025-03-23 14:55:46      cash   30.0
# 258  2025-03-23  2025-03-23 15:15:36      card   25.0
# 259  2025-03-23  2025-03-23 17:59:25      card   28.0
# 260  2025-03-23  2025-03-23 18:01:33      card   28.0
# 261  2025-03-23  2025-03-23 21:23:11      card   29.0
#
#                     coffee_name
# 0                           Tea
# 1                           Tea
# 2                      Espresso
# 3         Chocolate with coffee
# 4           Chocolate with milk
# ..                          ...
# 257                  Cappuccino
# 258               Irish whiskey
# 259             Super chocolate
# 260  Vanilla with Irish whiskey
# 261   Coffee with Irish whiskey
#
# [262 rows x 5 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
merged_data = pd.concat([data1, data2], ignore_index=True)
merged_data
# Out:
#             date                 datetime cash_type                 card  \
# 0     2024-03-01  2024-03-01 10:15:50.520      card  ANON-0000-0000-0001
# 1     2024-03-01  2024-03-01 12:19:22.539      card  ANON-0000-0000-0002
# 2     2024-03-01  2024-03-01 12:20:18.089      card  ANON-0000-0000-0002
# 3     2024-03-01  2024-03-01 13:46:33.006      card  ANON-0000-0000-0003
# 4     2024-03-01  2024-03-01 13:48:14.626      card  ANON-0000-0000-0004
# ...          ...                      ...       ...                  ...
# 3893  2025-03-23      2025-03-23 14:55:46      cash                  NaN
# 3894  2025-03-23      2025-03-23 15:15:36      card                  NaN
# 3895  2025-03-23      2025-03-23 17:59:25      card                  NaN
# 3896  2025-03-23      2025-03-23 18:01:33      card                  NaN
# 3897  2025-03-23      2025-03-23 21:23:11      card                  NaN
#
#       money                 coffee_name
# 0      38.7                       Latte
# 1      38.7               Hot Chocolate
# 2      38.7               Hot Chocolate
# 3      28.9                   Americano
# 4      38.7                       Latte
# ...     ...                         ...
# 3893   30.0                  Cappuccino
# 3894   25.0               Irish whiskey
# 3895   28.0             Super chocolate
# 3896   28.0  Vanilla with Irish whiskey
# 3897   29.0   Coffee with Irish whiskey
#
# [3898 rows x 6 columns]

# %%
merged_data.isnull().sum()
# Out:
# date             0
# datetime         0
# cash_type        0
# card           351
# money            0
# coffee_name      0
# dtype: int64

# %%
merged_data.dtypes
# Out:
# date            object
# datetime        object
# cash_type       object
# card            object
# money          float64
# coffee_name     object
# dtype: object

# %%
merged_data['datetime'] = pd.to_datetime(merged_data['datetime'], format='mixed')

# %% [markdown]
# ## Data analysis and visualization

# %%
coffee_counts = merged_data['coffee_name'].value_counts().reset_index()
coffee_counts.columns = ['coffee_name', 'count']

# %%
fig_coffee = px.bar(coffee_counts.head(20), x = 'coffee_name', y = 'count', title = 'Most Popular Coffee Types')

fig_coffee.update_layout(
    xaxis=dict(
        title=dict(
            text="Coffee Types"
        )
    ),
    yaxis=dict(
        title=dict(
            text="Number of Purchases"
        )
    ),
    font=dict(
        family="Roboto",
        size=18,
        color="RebeccaPurple"
    )
)

fig_coffee.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cff3b071-1ba6-455f-8fc2-19a10cf198d0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cff3b071-1ba6-455f-8fc2-19a10cf198d0")) {                    Plotly.newPlot(                        "cff3b071-1ba6-455f-8fc2-19a10cf198d0",                        [{"alignmentgroup":"True","hovertemplate":"coffee_name=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Americano with Milk","Latte","Americano","Cappuccino","Cortado","Hot Chocolate","Cocoa","Espresso","Americano with milk","Irish whiskey","Coffee with Irish whiskey","Tea","Irish whiskey with milk","Double Irish whiskey","Chocolate with milk","Caramel with Irish whiskey","Super chocolate","Chocolate with coffee","Mochaccino","Irish with chocolate"],"xaxis":"x","y":[824,806,593,517,292,282,243,152,44,21,16,16,15,12,12,8,6,5,5,5],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"s ...

# %%
sales = merged_data.groupby('coffee_name')['money'].sum().reset_index().sort_values(by='money', ascending=False)
sales.columns = ['coffee_name', 'money']
sales
# Out:
#                    coffee_name     money
# 28                       Latte  28658.30
# 1          Americano with Milk  25269.12
# 3                   Cappuccino  18514.14
# 0                    Americano  15437.26
# 23               Hot Chocolate  10172.46
# 12                       Cocoa   8678.16
# 15                     Cortado   7534.86
# 22                    Espresso   3187.28
# 2          Americano with milk   1100.00
# 25               Irish whiskey    525.00
# 13   Coffee with Irish whiskey    464.00
# 26     Irish whiskey with milk    405.00
# 16        Double Irish whiskey    336.00
# 11         Chocolate with milk    324.00
# 31                         Tea    240.00
# 6   Caramel with Irish whiskey    224.00
# 30             Super chocolate    168.00
# 10       Chocolate with coffee    150.00
# 29                  Mochaccino    150.00
# 27        Irish with chocolate    135.00
# 7       Caramel with chocolate    112.00
# 33  Vanilla with Irish whiskey     84.00
# 8            Caramel with milk     75.00
# 19   Double espresso with milk     64.00
# 5               Caramel coffee     56.00
# 21              Double vanilla     47.00
# 24               Hot milkshake     30.00
# 14       Coffee with chocolate     28.00
# 18             Double espresso     27.00
# 20            Double ristretto     27.00
# 32              Vanilla coffee     27.00
# 9                    Chocolate     25.00
# 17            Double chocolate     25.00
# 4                      Caramel     22.00

# %%
fig_sales = px.bar(sales, x = 'coffee_name', y = 'money', title = 'Total sales in different coffee')

fig_sales.update_layout(
    xaxis=dict(
        title=dict(
            text="Coffee Types"
        )
    ),
    yaxis=dict(
        title=dict(
            text="Total sales(money)"
        )
    ),
    font=dict(
        family="Roboto",
        size=18,
        color="RebeccaPurple"
    )
)

fig_sales.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d0cdb756-bdef-48ac-94cd-119d66798f80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0cdb756-bdef-48ac-94cd-119d66798f80")) {                    Plotly.newPlot(                        "d0cdb756-bdef-48ac-94cd-119d66798f80",                        [{"alignmentgroup":"True","hovertemplate":"coffee_name=%{x}\u003cbr\u003emoney=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Latte","Americano with Milk","Cappuccino","Americano","Hot Chocolate","Cocoa","Cortado","Espresso","Americano with milk","Irish whiskey","Coffee with Irish whiskey","Irish whiskey with milk","Double Irish whiskey","Chocolate with milk","Tea","Caramel with Irish whiskey","Super chocolate","Chocolate with coffee","Mochaccino","Irish with chocolate","Caramel with chocolate","Vanilla with Irish whiskey","Caramel with milk","Double espresso with milk","Caramel coffee","Double vanilla","Hot milkshake","Coffee with chocolate","Double espresso","Double ristretto","Vanilla coffee","Chocolate","Double chocolate","Caramel"],"xaxis":"x","y":[28658.3,25269.12,18514.14,15437.26,10172.46,8678.16,7534.86,3187.2799999999997,1100.0,525.0,464.0,405.0,336.0,324.0,240.0,224.0,168.0,150.0,150.0,135.0,112.0,84.0,75.0,64.0,56.0,47.0,30.0,28.0,27.0,27.0,27.0,25.0,25.0,22.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c 